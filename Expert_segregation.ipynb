# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv('C:/Users/goelk/OneDrive/Desktop/metadata_compiled.csv')    # upload metadata csv file on colab from the downloaded location on PC
df.head()
# Out:
#    Unnamed: 0                                  uuid  \
# 0           0  00014dcc-0f06-4c27-8c7b-737b18a2cf4c
# 1           1  00039425-7f3a-42aa-ac13-834aaa2b6b92
# 2           2  0007c6f1-5441-40e6-9aaf-a761d8f2da3b
# 3           3  00098cdb-4da1-4aa7-825a-4f1b9abc214b
# 4           4  0009eb28-d8be-4dc1-92bb-907e53bc5c7a
#
#                            datetime  cough_detected  latitude  longitude  \
# 0  2020-11-25T18:58:50.488301+00:00          0.0155      48.9        2.4
# 1  2020-04-13T21:30:59.801831+00:00          0.9609      31.3       34.8
# 2  2020-10-18T15:38:38.205870+00:00          0.1643       NaN        NaN
# 3  2021-01-22T22:08:06.742577+00:00          0.1133      47.4        9.4
# 4  2020-04-12T04:02:18.159383+00:00          0.9301      40.0      -75.1
#
#     age  gender respiratory_condition fever_muscle_pain  ... quality_4  \
# 0   NaN     NaN                   NaN               NaN  ...       NaN
# ...

# %%
data = df[df.cough_detected >= 0.8]   # Filtering dataset to contain samples without non-cough events
data.head()
# Out:
#     Unnamed: 0                                  uuid  \
# 1            1  00039425-7f3a-42aa-ac13-834aaa2b6b92
# 4            4  0009eb28-d8be-4dc1-92bb-907e53bc5c7a
# 6            6  001328dc-ea5d-4847-9ccf-c5aa2a3f2d0f
# 12          12  0028b68c-aca4-4f4f-bb1d-cb4ed5bbd952
# 13          13  00291cce-36a0-4a29-9e2d-c1d96ca17242
#
#                             datetime  cough_detected  latitude  longitude  \
# 1   2020-04-13T21:30:59.801831+00:00          0.9609      31.3       34.8
# 4   2020-04-12T04:02:18.159383+00:00          0.9301      40.0      -75.1
# 6   2020-04-13T22:23:06.997578+00:00          0.9968       NaN        NaN
# 12  2020-05-24T12:12:46.394647+00:00          0.8937       NaN        NaN
# 13  2020-04-13T15:10:58.405156+00:00          0.9883      39.4       67.2
#
#      age  gender respiratory_condition fever_muscle_pain  ... quality_4  \
# 1   15.0    male                 False             False  ...       NaN
# ...

# %%
data = data.drop(['datetime','latitude','longitude','respiratory_condition','fever_muscle_pain', 'status', 'status_SSL'], axis = 1)

# %%
data.shape
# Out:
# (18544, 45)

# %%
data = data.dropna(subset = ['age', 'gender'])

# %%
expert_1 = data.drop(['cough_type_2','severity_2','dyspnea_2','wheezing_2','stridor_2','choking_2','congestion_2','nothing_2','diagnosis_2','quality_2',
                      'cough_type_3','severity_3','dyspnea_3','wheezing_3','stridor_3','choking_3','congestion_3','nothing_3','diagnosis_3','quality_3',
                      'cough_type_4','severity_4','dyspnea_4','wheezing_4','stridor_4','choking_4','congestion_4','nothing_4','diagnosis_4','quality_4'], axis = 1)
expert_1
# Out:
#        Unnamed: 0                                  uuid  cough_detected   age  \
# 1               1  00039425-7f3a-42aa-ac13-834aaa2b6b92          0.9609  15.0
# 4               4  0009eb28-d8be-4dc1-92bb-907e53bc5c7a          0.9301  34.0
# 6               6  001328dc-ea5d-4847-9ccf-c5aa2a3f2d0f          0.9968  21.0
# 12             12  0028b68c-aca4-4f4f-bb1d-cb4ed5bbd952          0.8937  28.0
# 13             13  00291cce-36a0-4a29-9e2d-c1d96ca17242          0.9883  15.0
# ...           ...                                   ...             ...   ...
# 34421       34421  ffe0658f-bade-4654-ad79-40a468aabb03          0.9846  22.0
# 34422       34422  ffe13fcf-c5c2-4a6a-a9fc-e010f4f033c1          0.9485  31.0
# 34425       34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0
# 34426       34426  ffeea120-92a4-40f9-b692-c3865c7a983f          0.9784  22.0
# 34433       34433  fffd1834-6cf2-4782-bb30-04c31b46a1fe          0.9754  22.0
#
# ...

# %%
print(3)
# Out:
# 3

# %%
expert_1 = expert_1.dropna(subset = ['diagnosis_1'])
expert_1
# Out:
#        Unnamed: 0                                  uuid  cough_detected   age  \
# 266           266  01ff40e8-63e6-4570-a463-9778ea30cad7          0.9686  24.0
# 476           476  0379c586-c500-483c-83a6-95b63afe6931          0.9916  63.0
# 483           483  038592cb-c8db-4f55-8052-e20059146cb5          0.9824  28.0
# 513           513  03c33278-ad87-4a37-bf8f-3b1fdf69ecfd          0.9746  25.0
# 686           686  052fc88d-aa01-4422-85fd-f0ddebb8bd95          0.9584  24.0
# ...           ...                                   ...             ...   ...
# 34135       34135  fdbabb79-c296-4b93-9e02-06b290916fe7          0.9041  42.0
# 34205       34205  fe3ddef6-cf4c-4adf-b12d-bf5c5b79a5f4          0.9938  48.0
# 34264       34264  feabf097-bb15-4fdf-85ac-a9babbaf5d9e          0.9503  46.0
# 34272       34272  feb93862-2508-4ca7-a74e-77701bbcd3c0          0.8560  25.0
# 34319       34319  ff1234d7-7837-4ba7-842f-99fdc916baa9          0.9947  29.0
#
# ...

# %%
expert_1.columns
# Out:
# Index(['Unnamed: 0', 'uuid', 'cough_detected', 'age', 'gender', 'quality_1',
#        'cough_type_1', 'dyspnea_1', 'wheezing_1', 'stridor_1', 'choking_1',
#        'congestion_1', 'nothing_1', 'diagnosis_1', 'severity_1'],
#       dtype='object')

# %%
expert_1.to_csv('expert_1.csv')

# %%
expert_2 = data.drop(['cough_type_1','severity_1','dyspnea_1','wheezing_1','stridor_1','choking_1','congestion_1','nothing_1','diagnosis_1','quality_1',
                      'cough_type_3','severity_3','dyspnea_3','wheezing_3','stridor_3','choking_3','congestion_3','nothing_3','diagnosis_3','quality_3',
                      'cough_type_4','severity_4','dyspnea_4','wheezing_4','stridor_4','choking_4','congestion_4','nothing_4','diagnosis_4','quality_4'], axis = 1)
expert_2
# Out:
#        Unnamed: 0                                  uuid  cough_detected   age  \
# 1               1  00039425-7f3a-42aa-ac13-834aaa2b6b92          0.9609  15.0
# 4               4  0009eb28-d8be-4dc1-92bb-907e53bc5c7a          0.9301  34.0
# 6               6  001328dc-ea5d-4847-9ccf-c5aa2a3f2d0f          0.9968  21.0
# 12             12  0028b68c-aca4-4f4f-bb1d-cb4ed5bbd952          0.8937  28.0
# 13             13  00291cce-36a0-4a29-9e2d-c1d96ca17242          0.9883  15.0
# ...           ...                                   ...             ...   ...
# 34421       34421  ffe0658f-bade-4654-ad79-40a468aabb03          0.9846  22.0
# 34422       34422  ffe13fcf-c5c2-4a6a-a9fc-e010f4f033c1          0.9485  31.0
# 34425       34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0
# 34426       34426  ffeea120-92a4-40f9-b692-c3865c7a983f          0.9784  22.0
# 34433       34433  fffd1834-6cf2-4782-bb30-04c31b46a1fe          0.9754  22.0
#
# ...

# %%
expert_2 = expert_2.dropna(subset = ['diagnosis_2'])
expert_2
# Out:
#        Unnamed: 0                                  uuid  cough_detected   age  \
# 42             42  005b8518-03ba-4bf5-86d2-005541442357          0.9854  23.0
# 189           189  015ec831-e765-44ee-aefc-10dfd95dec78          0.9208  34.0
# 204           204  0177b817-0ba3-498a-bc05-48bc66cc91b8          0.8047  18.0
# 266           266  01ff40e8-63e6-4570-a463-9778ea30cad7          0.9686  24.0
# 392           392  02df470b-ddcf-403a-b726-76be6af905e1          0.8598  20.0
# ...           ...                                   ...             ...   ...
# 34019       34019  fcd7caa2-6034-457c-a8ab-6b838bf60d2b          0.9978  26.0
# 34208       34208  fe40afee-154b-4092-8626-baf91e2860ff          0.9887  59.0
# 34246       34246  fe8c855a-21ba-4f61-b274-3acff1ea5265          0.9782  17.0
# 34289       34289  fed03a5c-6329-488c-a031-213ccdceabcf          0.9820  32.0
# 34319       34319  ff1234d7-7837-4ba7-842f-99fdc916baa9          0.9947  29.0
#
# ...

# %%
expert_2.columns
# Out:
# Index(['Unnamed: 0', 'uuid', 'cough_detected', 'age', 'gender', 'quality_2',
#        'cough_type_2', 'dyspnea_2', 'wheezing_2', 'stridor_2', 'choking_2',
#        'congestion_2', 'nothing_2', 'diagnosis_2', 'severity_2'],
#       dtype='object')

# %%
expert_2.to_csv('expert_2.csv')

# %%
expert_3 = data.drop(['cough_type_1','severity_1','dyspnea_1','wheezing_1','stridor_1','choking_1','congestion_1','nothing_1','diagnosis_1','quality_1',
                      'cough_type_2','severity_2','dyspnea_2','wheezing_2','stridor_2','choking_2','congestion_2','nothing_2','diagnosis_2','quality_2',
                      'cough_type_4','severity_4','dyspnea_4','wheezing_4','stridor_4','choking_4','congestion_4','nothing_4','diagnosis_4','quality_4'], axis = 1)
expert_3
# Out:
#        Unnamed: 0                                  uuid  cough_detected   age  \
# 1               1  00039425-7f3a-42aa-ac13-834aaa2b6b92          0.9609  15.0
# 4               4  0009eb28-d8be-4dc1-92bb-907e53bc5c7a          0.9301  34.0
# 6               6  001328dc-ea5d-4847-9ccf-c5aa2a3f2d0f          0.9968  21.0
# 12             12  0028b68c-aca4-4f4f-bb1d-cb4ed5bbd952          0.8937  28.0
# 13             13  00291cce-36a0-4a29-9e2d-c1d96ca17242          0.9883  15.0
# ...           ...                                   ...             ...   ...
# 34421       34421  ffe0658f-bade-4654-ad79-40a468aabb03          0.9846  22.0
# 34422       34422  ffe13fcf-c5c2-4a6a-a9fc-e010f4f033c1          0.9485  31.0
# 34425       34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0
# 34426       34426  ffeea120-92a4-40f9-b692-c3865c7a983f          0.9784  22.0
# 34433       34433  fffd1834-6cf2-4782-bb30-04c31b46a1fe          0.9754  22.0
#
# ...

# %%
expert_3 = expert_3.dropna(subset = ['diagnosis_3'])
expert_3
# Out:
#        Unnamed: 0                                  uuid  cough_detected   age  \
# 70             70  008ba489-31ad-44d8-856b-fcf72369dc46          0.9962  28.0
# 71             71  008c1c9e-aeef-40c5-846c-24f1b964f884          0.9751  44.0
# 98             98  00bf9f83-2e8f-47cf-a4f2-97f2beceebc1          0.9815  37.0
# 110           110  00ce5b06-c302-4387-bbd7-86355a4a8c12          0.9900  41.0
# 115           115  00ddf050-6939-4f33-9e54-fcb309b895ec          0.9089  49.0
# ...           ...                                   ...             ...   ...
# 34185       34185  fe28d452-dc48-4c86-af5c-d8cee2e7105b          0.9054   1.0
# 34319       34319  ff1234d7-7837-4ba7-842f-99fdc916baa9          0.9947  29.0
# 34344       34344  ff49f6b7-fa54-4780-a4be-b0594e628aae          0.9540  17.0
# 34375       34375  ff8435f6-76b5-42c1-8f4c-7479710e71bf          0.9947  38.0
# 34407       34407  ffbeb867-cdb7-4226-9456-e74c80acf2d9          0.9647  30.0
#
# ...

# %%
expert_3.columns
# Out:
# Index(['Unnamed: 0', 'uuid', 'cough_detected', 'age', 'gender', 'quality_3',
#        'cough_type_3', 'dyspnea_3', 'wheezing_3', 'stridor_3', 'choking_3',
#        'congestion_3', 'nothing_3', 'diagnosis_3', 'severity_3'],
#       dtype='object')

# %%
expert_3.to_csv('expert_3.csv')

# %%
expert_4 = data.drop(['cough_type_1','severity_1','dyspnea_1','wheezing_1','stridor_1','choking_1','congestion_1','nothing_1','diagnosis_1','quality_1',
                      'cough_type_2','severity_2','dyspnea_2','wheezing_2','stridor_2','choking_2','congestion_2','nothing_2','diagnosis_2','quality_2',
                      'cough_type_3','severity_3','dyspnea_3','wheezing_3','stridor_3','choking_3','congestion_3','nothing_3','diagnosis_3','quality_3'], axis = 1)
expert_4
# Out:
#        Unnamed: 0                                  uuid  cough_detected   age  \
# 1               1  00039425-7f3a-42aa-ac13-834aaa2b6b92          0.9609  15.0
# 4               4  0009eb28-d8be-4dc1-92bb-907e53bc5c7a          0.9301  34.0
# 6               6  001328dc-ea5d-4847-9ccf-c5aa2a3f2d0f          0.9968  21.0
# 12             12  0028b68c-aca4-4f4f-bb1d-cb4ed5bbd952          0.8937  28.0
# 13             13  00291cce-36a0-4a29-9e2d-c1d96ca17242          0.9883  15.0
# ...           ...                                   ...             ...   ...
# 34421       34421  ffe0658f-bade-4654-ad79-40a468aabb03          0.9846  22.0
# 34422       34422  ffe13fcf-c5c2-4a6a-a9fc-e010f4f033c1          0.9485  31.0
# 34425       34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0
# 34426       34426  ffeea120-92a4-40f9-b692-c3865c7a983f          0.9784  22.0
# 34433       34433  fffd1834-6cf2-4782-bb30-04c31b46a1fe          0.9754  22.0
#
# ...

# %%
expert_4 = expert_4.dropna(subset = ['diagnosis_4'])
expert_4
# Out:
#        Unnamed: 0                                  uuid  cough_detected   age  \
# 14             14  0029d048-898a-4c70-89c7-0815cdcf7391          0.9456  35.0
# 185           185  015576c8-2b03-4dcb-b251-78a984fe86fe          0.9944  27.0
# 192           192  01614a4a-947f-43ca-a609-fc2787509f6f          0.9380  23.0
# 207           207  01820f7c-b953-4faf-aa13-978cfda6b08e          0.8139  39.0
# 266           266  01ff40e8-63e6-4570-a463-9778ea30cad7          0.9686  24.0
# ...           ...                                   ...             ...   ...
# 34119       34119  fd9c0574-c559-4301-bab9-bbf45e64ed40          0.9731  28.0
# 34276       34276  febc1922-0a6f-4667-8f5a-d28efdcd993d          0.9591  33.0
# 34319       34319  ff1234d7-7837-4ba7-842f-99fdc916baa9          0.9947  29.0
# 34413       34413  ffd18a56-096d-40fc-9862-e5c5a8ca1fcd          0.9953  25.0
# 34425       34425  ffedc843-bfc2-4ad6-a749-2bc86bdac84a          0.9498  23.0
#
# ...

# %%
expert_4.columns
# Out:
# Index(['Unnamed: 0', 'uuid', 'cough_detected', 'age', 'gender', 'quality_4',
#        'cough_type_4', 'dyspnea_4', 'wheezing_4', 'stridor_4', 'choking_4',
#        'congestion_4', 'nothing_4', 'diagnosis_4', 'severity_4'],
#       dtype='object')

# %%
expert_4.to_csv('expert_4.csv')
