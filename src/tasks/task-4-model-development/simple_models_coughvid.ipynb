# %% [markdown]
#  TRAINING SIMPLE MODELS LIKE XGBOOST AND ANN ON COUGHVID DATASET

# %%
import pandas as pd
import os
import numpy as np
import IPython.display as ipd
import librosa
import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Download dataset from "https://www.kaggle.com/datasets/nasrulhakim86/coughvid-wav"
# Extract it and add the path location

# %%
audio_dataset_path = 'D:/work3/Omdena/NewDelhi_Chapter/data/archive/public_dataset/'
metadata_file_path = 'D:/work3/Omdena/NewDelhi_Chapter/data/archive/public_dataset/metadata_compiled.csv'

# %%
#READ THE METADATA FILE
metadf = pd.read_csv(metadata_file_path)
metadf.head()
# Out:
#                                    uuid                          datetime  \
# 0  00014dcc-0f06-4c27-8c7b-737b18a2cf4c  2020-11-25T18:58:50.488301+00:00
# 1  00039425-7f3a-42aa-ac13-834aaa2b6b92  2020-04-13T21:30:59.801831+00:00
# 2  0007c6f1-5441-40e6-9aaf-a761d8f2da3b  2020-10-18T15:38:38.205870+00:00
# 3  0009eb28-d8be-4dc1-92bb-907e53bc5c7a  2020-04-12T04:02:18.159383+00:00
# 4  0012c608-33d0-4ef7-bde3-75a0b1a0024e  2020-04-15T01:03:59.029326+00:00
#
#    cough_detected        SNR  latitude  longitude   age  gender  \
# 0          0.0155   7.326171      48.9        2.4   NaN     NaN
# 1          0.9609  16.151433      31.3       34.8  15.0    male
# 2          0.1643  16.217201       NaN        NaN  46.0  female
# 3          0.9301  20.146058      40.0      -75.1  34.0    male
# 4          0.0482   0.000000     -16.5      -71.5   NaN     NaN
#
#   respiratory_condition fever_muscle_pain  ... quality_4 cough_type_4  \
# 0                   NaN               NaN  ...       NaN          NaN
# 1                 False             False  ...       NaN          NaN
# 2                 False             False  ...       NaN          NaN
# 3                  True             False  ...       NaN          NaN
# 4                   NaN               NaN  ...       NaN          NaN
#
#   dyspnea_4 wheezing_4 stridor_4 choking_4 congestion_4 nothing_4 diagnosis_4  \
# 0       NaN        NaN       NaN       NaN          NaN       NaN         NaN
# 1       NaN        NaN       NaN       NaN          NaN       NaN         NaN
# 2       NaN        NaN       NaN       NaN          NaN       NaN         NaN
# 3       NaN        NaN       NaN       NaN          NaN       NaN         NaN
# 4       NaN        NaN       NaN       NaN          NaN       NaN         NaN
#
#   severity_4
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 51 columns]

# %%
print(metadf.columns)
# Out:
# Index(['uuid', 'datetime', 'cough_detected', 'SNR', 'latitude', 'longitude',
#        'age', 'gender', 'respiratory_condition', 'fever_muscle_pain', 'status',
#        'quality_1', 'cough_type_1', 'dyspnea_1', 'wheezing_1', 'stridor_1',
#        'choking_1', 'congestion_1', 'nothing_1', 'diagnosis_1', 'severity_1',
#        'quality_2', 'cough_type_2', 'dyspnea_2', 'wheezing_2', 'stridor_2',
#        'choking_2', 'congestion_2', 'nothing_2', 'diagnosis_2', 'severity_2',
#        'quality_3', 'cough_type_3', 'dyspnea_3', 'wheezing_3', 'stridor_3',
#        'choking_3', 'congestion_3', 'nothing_3', 'diagnosis_3', 'severity_3',
#        'quality_4', 'cough_type_4', 'dyspnea_4', 'wheezing_4', 'stridor_4',
#        'choking_4', 'congestion_4', 'nothing_4', 'diagnosis_4', 'severity_4'],
#       dtype='object')

# %%
# status is the diagnosis result
# quality_1 -> severity_1 is annoted by physician 1 , similarly for other three physicians

# %%
metadf['status'].value_counts()
# Out:
# healthy        12479
# symptomatic     2590
# COVID-19        1155
# Name: status, dtype: int64

# %%
#metadf['respiratory_condition'].value_counts()
# Out:
# False    13403
# True      2821
# Name: respiratory_condition, dtype: int64

# %%
#metadf['fever_muscle_pain'].value_counts()
# Out:
# False    14296
# True      1928
# Name: fever_muscle_pain, dtype: int64

# %%
#metadf['cough_detected'].value_counts()
# Out:
# 1.0000    2816
# 0.0000     106
# 0.9956      55
# 0.9958      52
# 0.9955      51
#           ...
# 0.1348       1
# 0.0027       1
# 0.1947       1
# 0.4124       1
# 0.5257       1
# Name: cough_detected, Length: 7212, dtype: int64

# %%
metadf2 = metadf[((metadf['cough_detected'] > 0.99) & (metadf['status'] == 'healthy')) |
                 ((metadf['cough_detected'] > 0) & (metadf['status'] == 'COVID-19')) |
                 ((metadf['cough_detected'] > 0) & (metadf['status'] == 'symptomatic'))]

# %%
# This would create a bit more balanced dataset
'''
metadf2 = metadf[((metadf['cough_detected'] > 0.996) & (metadf['status'] == 'healthy')) |
                 ((metadf['cough_detected'] > 0.5) & (metadf['status'] == 'COVID-19')) |
                 ((metadf['cough_detected'] > 0.98) & (metadf['status'] == 'symptomatic'))]
'''

# %%
metadf2['status'].value_counts()
# Out:
# healthy        2761
# symptomatic    2575
# COVID-19       1133
# Name: status, dtype: int64

# %%
#metadf2['cough_detected'].value_counts()
# Out:
# 1.0000    2500
# 0.9958      42
# 0.9955      42
# 0.9936      39
# 0.9956      38
#           ...
# 0.8955       1
# 0.0260       1
# 0.5336       1
# 0.3786       1
# 0.5257       1
# Name: cough_detected, Length: 1581, dtype: int64

# %%
#metadf2['respiratory_condition'].value_counts()
# Out:
# False    2878
# True      982
# Name: respiratory_condition, dtype: int64

# %%
#metadf2['fever_muscle_pain'].value_counts()
# Out:
# False    3095
# True      765
# Name: fever_muscle_pain, dtype: int64

# %%
#metadf2['quality_1'].value_counts()
# Out:
# ok      521
# poor    137
# good     31
# Name: quality_1, dtype: int64

# %%
#metadf2['cough_type_1'].value_counts()
# Out:
# dry        368
# unknown    263
# wet         58
# Name: cough_type_1, dtype: int64

# %%
#metadf2['dyspnea_1'].value_counts()
# Out:
# False    685
# True       4
# Name: dyspnea_1, dtype: int64

# %%
#metadf2['wheezing_1'].value_counts()
# Out:
# False    640
# True      49
# Name: wheezing_1, dtype: int64

# %%
#metadf2['stridor_1'].value_counts()
# Out:
# False    689
# Name: stridor_1, dtype: int64

# %%
#metadf2['choking_1'].value_counts()
# Out:
# False    688
# True       1
# Name: choking_1, dtype: int64

# %%
#metadf2['congestion_1'].value_counts()
# Out:
# False    675
# True      14
# Name: congestion_1, dtype: int64

# %%
#metadf2['nothing_1'].value_counts()
# Out:
# True     625
# False     64
# Name: nothing_1, dtype: int64

# %%
#metadf2['diagnosis_1'].value_counts()
# Out:
# COVID-19               244
# healthy_cough          207
# lower_infection        204
# upper_infection         20
# obstructive_disease     14
# Name: diagnosis_1, dtype: int64

# %%
#metadf2['severity_1'].value_counts()
# Out:
# mild           447
# pseudocough    199
# severe          31
# unknown         12
# Name: severity_1, dtype: int64

# %%
newdf = metadf2

# %%
# This takes only good and ok quality audios dicarding poor quality ones
'''
newdf = metadf[(((metadf['cough_detected'] > 0.5) & (metadf['status'] == 'healthy')) 
                & (((metadf['quality_1'] == 'good') | (metadf['quality_1'] == 'ok')) |
                 ((metadf['quality_2'] == 'good') | (metadf['quality_2'] == 'ok')) |
                 ((metadf['quality_3'] == 'good') | (metadf['quality_3'] == 'ok')) |
                 ((metadf['quality_4'] == 'good') | (metadf['quality_4'] == 'ok')))) 
                 |
                 (((metadf['cough_detected'] > 0.5) & (metadf['status'] == 'symptomatic')) 
                & (((metadf['quality_1'] == 'good') | (metadf['quality_1'] == 'ok')) |
                 ((metadf['quality_2'] == 'good') | (metadf['quality_2'] == 'ok')) |
                 ((metadf['quality_3'] == 'good') | (metadf['quality_3'] == 'ok')) |
                 ((metadf['quality_4'] == 'good') | (metadf['quality_4'] == 'ok'))))
                 |
                 ((metadf['cough_detected'] > 0) & (metadf['status'] == 'COVID-19'))]
'''

# %%
newdf
# Out:
#                                        uuid                          datetime  \
# 5      001328dc-ea5d-4847-9ccf-c5aa2a3f2d0f  2020-04-13T22:23:06.997578+00:00
# 7      001d8e33-a4af-4edb-98ba-b03f891d9a6c  2020-05-13T01:27:42.552773+00:00
# 12     0029d048-898a-4c70-89c7-0815cdcf7391  2020-07-16T03:01:55.059762+00:00
# 13     002d28bc-7806-4dfb-9c9b-afa8cb623cac  2020-04-16T22:10:24.107938+00:00
# 17     00357712-dd5a-4c0a-90a4-39f1f4b9d5fd  2020-04-10T12:48:17.554497+00:00
# ...                                     ...                               ...
# 27534  ffd18a56-096d-40fc-9862-e5c5a8ca1fcd  2020-04-14T05:56:02.587585+00:00
# 27539  ffe0658f-bade-4654-ad79-40a468aabb03  2020-04-14T01:58:32.200245+00:00
# 27540  ffe13fcf-c5c2-4a6a-a9fc-e010f4f033c1  2020-04-13T21:08:50.708320+00:00
# 27542  ffedc843-bfc2-4ad6-a749-2bc86bdac84a  2020-06-05T03:41:37.481463+00:00
# 27546  fff3ff61-2387-4139-938b-539db01e6be5  2020-06-28T21:28:21.530881+00:00
#
#        cough_detected        SNR  latitude  longitude   age  gender  \
# 5              0.9968  13.146502       NaN        NaN  21.0    male
# 7              0.0306  12.713480      13.8      -89.6   NaN  female
# 12             1.0000   9.624196       NaN        NaN  35.0    male
# 13             0.9959  35.641847       NaN        NaN  46.0  female
# 17             0.0576   0.000000      46.8        6.6   NaN    male
# ...               ...        ...       ...        ...   ...     ...
# 27534          1.0000  12.290065      46.5        6.6  25.0  female
# 27539          1.0000  21.960583      41.6       60.9  22.0    male
# 27540          0.9485   9.966762      41.1       28.8  31.0    male
# 27542          1.0000  33.661082     -34.5      -58.5  23.0    male
# 27546          0.5257  43.932829      51.6       -0.2   NaN  female
#
#       respiratory_condition fever_muscle_pain  ... quality_4 cough_type_4  \
# 5                     False             False  ...       NaN          NaN
# 7                     False              True  ...       NaN          NaN
# 12                     True             False  ...      good          dry
# 13                    False             False  ...       NaN          NaN
# 17                     True             False  ...       NaN          NaN
# ...                     ...               ...  ...       ...          ...
# 27534                 False             False  ...        ok          dry
# 27539                  True              True  ...      poor      unknown
# 27540                 False             False  ...       NaN          NaN
# 27542                 False             False  ...      good          dry
# 27546                 False             False  ...       NaN          NaN
#
#       dyspnea_4 wheezing_4 stridor_4 choking_4 congestion_4 nothing_4  \
# 5           NaN        NaN       NaN       NaN          NaN       NaN
# 7           NaN        NaN       NaN       NaN          NaN       NaN
# 12        False      False     False     False        False      True
# 13          NaN        NaN       NaN       NaN          NaN       NaN
# 17          NaN        NaN       NaN       NaN          NaN       NaN
# ...         ...        ...       ...       ...          ...       ...
# 27534     False      False     False     False        False      True
# 27539     False      False     False     False        False     False
# 27540       NaN        NaN       NaN       NaN          NaN       NaN
# 27542     False      False     False     False        False      True
# 27546       NaN        NaN       NaN       NaN          NaN       NaN
#
#            diagnosis_4   severity_4
# 5                  NaN          NaN
# 7                  NaN          NaN
# 12     upper_infection         mild
# 13                 NaN          NaN
# 17                 NaN          NaN
# ...                ...          ...
# 27534         COVID-19         mild
# 27539              NaN      unknown
# 27540              NaN          NaN
# 27542    healthy_cough  pseudocough
# 27546              NaN          NaN
#
# [6469 rows x 51 columns]

# %%
# This indicates we have a somewhat balanced dataset
newdf['status'].value_counts()
# Out:
# healthy        2761
# symptomatic    2575
# COVID-19       1133
# Name: status, dtype: int64

# %%
# if there are missing values NAN present fill them with empty string
newdf = newdf.fillna("")

# %%
# if any data has status missing drop them
newdf.drop(newdf.loc[newdf['status']==""].index, inplace=True)

# %%
newdf
# Out:
#                                        uuid                          datetime  \
# 5      001328dc-ea5d-4847-9ccf-c5aa2a3f2d0f  2020-04-13T22:23:06.997578+00:00
# 7      001d8e33-a4af-4edb-98ba-b03f891d9a6c  2020-05-13T01:27:42.552773+00:00
# 12     0029d048-898a-4c70-89c7-0815cdcf7391  2020-07-16T03:01:55.059762+00:00
# 13     002d28bc-7806-4dfb-9c9b-afa8cb623cac  2020-04-16T22:10:24.107938+00:00
# 17     00357712-dd5a-4c0a-90a4-39f1f4b9d5fd  2020-04-10T12:48:17.554497+00:00
# ...                                     ...                               ...
# 27534  ffd18a56-096d-40fc-9862-e5c5a8ca1fcd  2020-04-14T05:56:02.587585+00:00
# 27539  ffe0658f-bade-4654-ad79-40a468aabb03  2020-04-14T01:58:32.200245+00:00
# 27540  ffe13fcf-c5c2-4a6a-a9fc-e010f4f033c1  2020-04-13T21:08:50.708320+00:00
# 27542  ffedc843-bfc2-4ad6-a749-2bc86bdac84a  2020-06-05T03:41:37.481463+00:00
# 27546  fff3ff61-2387-4139-938b-539db01e6be5  2020-06-28T21:28:21.530881+00:00
#
#        cough_detected        SNR latitude longitude   age  gender  \
# 5              0.9968  13.146502                     21.0    male
# 7              0.0306  12.713480     13.8     -89.6        female
# 12             1.0000   9.624196                     35.0    male
# 13             0.9959  35.641847                     46.0  female
# 17             0.0576   0.000000     46.8       6.6          male
# ...               ...        ...      ...       ...   ...     ...
# 27534          1.0000  12.290065     46.5       6.6  25.0  female
# 27539          1.0000  21.960583     41.6      60.9  22.0    male
# 27540          0.9485   9.966762     41.1      28.8  31.0    male
# 27542          1.0000  33.661082    -34.5     -58.5  23.0    male
# 27546          0.5257  43.932829     51.6      -0.2        female
#
#        respiratory_condition  fever_muscle_pain  ... quality_4 cough_type_4  \
# 5                      False              False  ...
# 7                      False               True  ...
# 12                      True              False  ...      good          dry
# 13                     False              False  ...
# 17                      True              False  ...
# ...                      ...                ...  ...       ...          ...
# 27534                  False              False  ...        ok          dry
# 27539                   True               True  ...      poor      unknown
# 27540                  False              False  ...
# 27542                  False              False  ...      good          dry
# 27546                  False              False  ...
#
#       dyspnea_4 wheezing_4 stridor_4 choking_4 congestion_4 nothing_4  \
# 5
# 7
# 12        False      False     False     False        False      True
# 13
# 17
# ...         ...        ...       ...       ...          ...       ...
# 27534     False      False     False     False        False      True
# 27539     False      False     False     False        False     False
# 27540
# 27542     False      False     False     False        False      True
# 27546
#
#            diagnosis_4   severity_4
# 5
# 7
# 12     upper_infection         mild
# 13
# 17
# ...                ...          ...
# 27534         COVID-19         mild
# 27539                       unknown
# 27540
# 27542    healthy_cough  pseudocough
# 27546
#
# [6469 rows x 51 columns]

# %%
# Feature Extraction Process
def features_extractor(file_name):
    audio, sample_rate = librosa.load(file_name)

    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=120)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)

    mel_spectrogram = librosa.feature.melspectrogram(y=audio, sr=sample_rate, n_fft=2048, hop_length=512, n_mels=120)
    mel_scaled_features = np.mean(mel_spectrogram.T,axis=0)

    #stft = np.abs(librosa.stft(audio))
    #chroma = librosa.feature.chroma_stft(S=stft, sr=sample_rate)
    #chroma_scaled_features = np.mean(chroma.T,axis=0)


    return mfccs_scaled_features, mel_scaled_features #, chroma_scaled_features

# %%
import numpy as np
from tqdm import tqdm
# Extract Mel Frequency Cepstral Coefficients and Mel Spectogram
extracted_features=[]
for index_num,row in tqdm(newdf.iterrows()):
    file_name = os.path.join(audio_dataset_path,str(row["uuid"])+".wav")
    final_class_labels=row["status"]
    mfcc, melspec = features_extractor(file_name)
    extracted_features.append([mfcc,melspec,final_class_labels])
# Out:
# 6469it [06:29, 16.62it/s]

# %%
### converting extracted_features to Pandas dataframe
extracted_features_df = pd.DataFrame(extracted_features,columns=['feature1','feature2','status'])
extracted_features_df.head()
# Out:
#                                             feature1  \
# 0  [-519.8622, 26.079721, -28.713432, 7.9876924, ...
# 1  [-517.534, 125.805275, -59.390606, -13.782511,...
# 2  [-492.71045, 16.865747, -3.735841, -0.9161602,...
# 3  [-507.23135, 19.040976, -16.899456, 5.4804497,...
# 4  [-957.87195, -0.9061077, -0.47938585, -3.27202...
#
#                                             feature2       status
# 0  [0.0039322926, 0.004463251, 0.0053868056, 0.01...      healthy
# 1  [7.889548e-05, 0.00024454814, 0.0031558843, 0....     COVID-19
# 2  [0.038029645, 0.16992389, 0.6232339, 1.2242541...  symptomatic
# 3  [0.0047508236, 0.005179205, 0.02720949, 0.2381...      healthy
# 4  [4.0905026e-09, 7.621856e-09, 1.6527492e-08, 4...     COVID-19

# %%
# Storing extracted features into a parquet file
extracted_features_df.to_parquet("mfcc_60_coughvid.parquet", index=False)

# %%
### Split the dataset into independent and dependent dataset
X1 = np.array(extracted_features_df['feature1'].tolist())
X2 = np.array(extracted_features_df['feature2'].tolist())
#X3 = np.array(extracted_features_df['feature3'].tolist()) #for a third feature (applicable if taken)
X = np.concatenate((X1, X2), axis=1)
#X = np.concatenate((X, X3), axis=1)
y = np.array(extracted_features_df['status'].tolist())

# %%
X
# Out:
# array([[-5.19862183e+02,  2.60797215e+01, -2.87134323e+01, ...,
#          4.26778577e-08,  2.67732609e-08,  3.23966187e-09],
#        [-5.17533997e+02,  1.25805275e+02, -5.93906059e+01, ...,
#          1.25279271e-08,  1.05582219e-08,  5.53928947e-09],
#        [-4.92710449e+02,  1.68657475e+01, -3.73584104e+00, ...,
#          1.76120568e-02,  9.76194628e-03,  5.92030294e-04],
#        ...,
#        [-4.77452209e+02,  5.04670677e+01, -2.13637428e+01, ...,
#          7.69107711e-09,  6.23341023e-09,  1.12702825e-09],
#        [-4.20832428e+02,  2.41599216e+01, -7.46264648e+00, ...,
#          2.17387930e-09,  1.42950074e-09,  1.53838012e-10],
#        [-4.48928497e+02,  3.12053547e+01, -5.50211754e+01, ...,
#          3.27644134e-09,  2.14461071e-09,  2.79460177e-10]], dtype=float32)

# %%
X.shape
# Out:
# (6469, 240)

# %%
### Label Encoding
y=np.array(pd.get_dummies(y))

# %%
y.shape
# Out:
# (6469, 3)

# %%
### Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
# Testa nd Validation Split
from sklearn.model_selection import train_test_split
X_val,X_test,y_val,y_test=train_test_split(X_test,y_test,test_size=0.5,random_state=0)

# %%
X_train
# Out:
# array([[-4.5111914e+02,  4.7152843e+01, -7.9044811e-02, ...,
#          3.8239052e-09,  2.4812994e-09,  3.7878933e-10],
#        [-4.7834470e+02,  9.5170235e+01, -8.1451263e+00, ...,
#          2.6923386e-04,  2.4025983e-04,  2.6154188e-05],
#        [-3.7469168e+02,  4.0205624e+01, -1.5869018e+01, ...,
#          2.7699492e-05,  1.4439714e-05,  1.8439455e-06],
#        ...,
#        [-5.2719574e+02,  2.8273001e+01, -1.0320598e+01, ...,
#          4.7467261e-09,  2.9470706e-09,  3.3408623e-10],
#        [-4.9230304e+02,  5.6945549e+01, -4.4023633e+00, ...,
#          4.3626711e-09,  2.8371292e-09,  3.2789638e-10],
#        [-3.7632587e+02,  4.5872734e+01, -1.6520857e+01, ...,
#          7.7681995e-07,  4.9443361e-07,  5.2558903e-08]], dtype=float32)

# %%
y
# Out:
# array([[0, 1, 0],
#        [1, 0, 0],
#        [0, 0, 1],
#        ...,
#        [0, 0, 1],
#        [0, 1, 0],
#        [0, 0, 1]], dtype=uint8)

# %%
X_train.shape
# Out:
# (4528, 240)

# %%
X_val.shape
# Out:
# (970, 240)

# %%
X_test.shape
# Out:
# (971, 240)

# %%
y_train.shape
# Out:
# (4528, 3)

# %%
y_val.shape
# Out:
# (970, 3)

# %%
y_test.shape
# Out:
# (971, 3)

# %%
# TRAIN an XGBOOST MODEL

# %%
# Define the model
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
model = XGBClassifier()

# %%
# Train the model
model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, ...)

# %%
# Get the predictions
y_pred = model.predict(X_test)
predictions = [np.round(x) for x in y_pred]

# %%
# Check the accuracy
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 39.96%

# %%
# Train an ANN model

# %%
# Define the model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics

### No of classes
num_labels = y.shape[1]

model=Sequential()
#First Layer
model.add(Dense(1024,input_shape=(240,)))
model.add(Activation('relu'))
model.add(Dropout(0.50))

#Second Layer
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.30))

#Third Layer
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.25))

#Fourth Layer
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.25))

#Final Layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_59 (Dense)            (None, 1024)              246784
#
#  activation_49 (Activation)  (None, 1024)              0
#
#  dropout_44 (Dropout)        (None, 1024)              0
#
#  dense_60 (Dense)            (None, 512)               524800
#
#  activation_50 (Activation)  (None, 512)               0
#
#  dropout_45 (Dropout)        (None, 512)               0
#
#  dense_61 (Dense)            (None, 256)               131328
#
#  activation_51 (Activation)  (None, 256)               0
#
#  dropout_46 (Dropout)        (None, 256)               0
#
#  dense_62 (Dense)            (None, 128)               32896
#
#  activation_52 (Activation)  (None, 128)               0
#
#  dropout_47 (Dropout)        (None, 128)               0
#
#  dense_63 (Dense)            (None, 3)                 387
#
#  activation_53 (Activation)  (None, 3)                 0
#
# =================================================================
# Total params: 936,195
# Trainable params: 936,195
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model with loss and optimizer
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
# Train the model
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 

num_epochs = 200
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='audio_classification_v1.0.hdf5', verbose=1, save_best_only=True)
start = datetime.now()

model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_val, y_val), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/200
# 142/142 [==============================] - ETA: 0s - loss: 3.6936 - accuracy: 0.3810
# Epoch 1: val_loss improved from inf to 1.05768, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 4s 16ms/step - loss: 3.6936 - accuracy: 0.3810 - val_loss: 1.0577 - val_accuracy: 0.3567
# Epoch 2/200
# 138/142 [============================>.] - ETA: 0s - loss: 1.2862 - accuracy: 0.3963
# Epoch 2: val_loss improved from 1.05768 to 1.04468, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 2s 16ms/step - loss: 1.2843 - accuracy: 0.3958 - val_loss: 1.0447 - val_accuracy: 0.4907
# Epoch 3/200
# 140/142 [============================>.] - ETA: 0s - loss: 1.1390 - accuracy: 0.4107
# Epoch 3: val_loss did not improve from 1.04468
# 142/142 [==============================] - 2s 12ms/step - loss: 1.1380 - accuracy: 0.4119 - val_loss: 1.0637 - val_accuracy: 0.3680
# Epoch 4/200
# 139/142 [============================>.] - ETA: 0s - loss: 1.1003 - accuracy: 0.4152
# Epoch 4: val_loss improved from 1.04468 to 1.03995, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 2s 13ms/step - loss: 1.1011 - accuracy: 0.4156 - val_loss: 1.0400 - val_accuracy: 0.4546
# Epoch 5/200
# 141/142 [============================>.] - ETA: 0s - loss: 1.0608 - accuracy: 0.4426
# Epoch 5: val_loss improved from 1.03995 to 1.03123, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 3s 19ms/step - loss: 1.0607 - accuracy: 0.4432 - val_loss: 1.0312 - val_accuracy: 0.4577
# Epoch 6/200
# 136/142 [===========================>..] - ETA: 0s - loss: 1.0429 - accuracy: 0.4511
# Epoch 6: val_loss improved from 1.03123 to 1.02269, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 1s 10ms/step - loss: 1.0434 - accuracy: 0.4519 - val_loss: 1.0227 - val_accuracy: 0.5072
# Epoch 7/200
# 137/142 [===========================>..] - ETA: 0s - loss: 1.0252 - accuracy: 0.4617
# Epoch 7: val_loss improved from 1.02269 to 0.99962, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 1s 10ms/step - loss: 1.0253 - accuracy: 0.4625 - val_loss: 0.9996 - val_accuracy: 0.5309
# Epoch 8/200
# 141/142 [============================>.] - ETA: 0s - loss: 1.0101 - accuracy: 0.4774
# Epoch 8: val_loss did not improve from 0.99962
# 142/142 [==============================] - 1s 9ms/step - loss: 1.0096 - accuracy: 0.4779 - val_loss: 1.0017 - val_accuracy: 0.5216
# Epoch 9/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.9908 - accuracy: 0.4940
# Epoch 9: val_loss improved from 0.99962 to 0.97252, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 1s 10ms/step - loss: 0.9901 - accuracy: 0.4943 - val_loss: 0.9725 - val_accuracy: 0.5299
# Epoch 10/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.9781 - accuracy: 0.5075
# Epoch 10: val_loss improved from 0.97252 to 0.96364, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 1s 10ms/step - loss: 0.9774 - accuracy: 0.5084 - val_loss: 0.9636 - val_accuracy: 0.5505
# Epoch 11/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.9769 - accuracy: 0.5167
# Epoch 11: val_loss improved from 0.96364 to 0.96035, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 1s 10ms/step - loss: 0.9768 - accuracy: 0.5157 - val_loss: 0.9604 - val_accuracy: 0.5495
# Epoch 12/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.9639 - accuracy: 0.5197
# Epoch 12: val_loss improved from 0.96035 to 0.94975, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 1s 10ms/step - loss: 0.9637 - accuracy: 0.5208 - val_loss: 0.9497 - val_accuracy: 0.5536
# Epoch 13/200
# 142/142 [==============================] - ETA: 0s - loss: 0.9588 - accuracy: 0.5263
# Epoch 13: val_loss did not improve from 0.94975
# 142/142 [==============================] - 1s 10ms/step - loss: 0.9588 - accuracy: 0.5263 - val_loss: 0.9510 - val_accuracy: 0.5608
# Epoch 14/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.9495 - accuracy: 0.5360
# Epoch 14: val_loss improved from 0.94975 to 0.94949, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 1s 9ms/step - loss: 0.9481 - accuracy: 0.5382 - val_loss: 0.9495 - val_accuracy: 0.5557
# Epoch 15/200
# 136/142 [===========================>..] - ETA: 0s - loss: 0.9420 - accuracy: 0.5441
# Epoch 15: val_loss improved from 0.94949 to 0.93292, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 1s 9ms/step - loss: 0.9421 - accuracy: 0.5428 - val_loss: 0.9329 - val_accuracy: 0.5577
# Epoch 16/200
# 136/142 [===========================>..] - ETA: 0s - loss: 0.9383 - accuracy: 0.5478
# Epoch 16: val_loss did not improve from 0.93292
# 142/142 [==============================] - 1s 9ms/step - loss: 0.9376 - accuracy: 0.5470 - val_loss: 0.9351 - val_accuracy: 0.5588
# Epoch 17/200
# 142/142 [==============================] - ETA: 0s - loss: 0.9363 - accuracy: 0.5426
# Epoch 17: val_loss improved from 0.93292 to 0.93247, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 1s 9ms/step - loss: 0.9363 - accuracy: 0.5426 - val_loss: 0.9325 - val_accuracy: 0.5608
# Epoch 18/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.9216 - accuracy: 0.5650
# Epoch 18: val_loss did not improve from 0.93247
# 142/142 [==============================] - 1s 9ms/step - loss: 0.9219 - accuracy: 0.5649 - val_loss: 0.9369 - val_accuracy: 0.5639
# Epoch 19/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.9345 - accuracy: 0.5491
# Epoch 19: val_loss did not improve from 0.93247
# 142/142 [==============================] - 1s 9ms/step - loss: 0.9347 - accuracy: 0.5492 - val_loss: 0.9346 - val_accuracy: 0.5577
# Epoch 20/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.9249 - accuracy: 0.5609
# Epoch 20: val_loss did not improve from 0.93247
# 142/142 [==============================] - 1s 9ms/step - loss: 0.9247 - accuracy: 0.5601 - val_loss: 0.9365 - val_accuracy: 0.5577
# Epoch 21/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.9211 - accuracy: 0.5594
# Epoch 21: val_loss improved from 0.93247 to 0.92465, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 1s 10ms/step - loss: 0.9211 - accuracy: 0.5592 - val_loss: 0.9247 - val_accuracy: 0.5701
# Epoch 22/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.9161 - accuracy: 0.5627
# Epoch 22: val_loss improved from 0.92465 to 0.91777, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 2s 11ms/step - loss: 0.9165 - accuracy: 0.5614 - val_loss: 0.9178 - val_accuracy: 0.5763
# Epoch 23/200
# 142/142 [==============================] - ETA: 0s - loss: 0.9183 - accuracy: 0.5665
# Epoch 23: val_loss did not improve from 0.91777
# 142/142 [==============================] - 1s 9ms/step - loss: 0.9183 - accuracy: 0.5665 - val_loss: 0.9245 - val_accuracy: 0.5794
# Epoch 24/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.9096 - accuracy: 0.5683
# Epoch 24: val_loss did not improve from 0.91777
# 142/142 [==============================] - 1s 9ms/step - loss: 0.9105 - accuracy: 0.5685 - val_loss: 0.9413 - val_accuracy: 0.5691
# Epoch 25/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.9157 - accuracy: 0.5607
# Epoch 25: val_loss did not improve from 0.91777
# 142/142 [==============================] - 1s 9ms/step - loss: 0.9170 - accuracy: 0.5610 - val_loss: 0.9238 - val_accuracy: 0.5856
# Epoch 26/200
# 142/142 [==============================] - ETA: 0s - loss: 0.8975 - accuracy: 0.5784
# Epoch 26: val_loss did not improve from 0.91777
# 142/142 [==============================] - 1s 9ms/step - loss: 0.8975 - accuracy: 0.5784 - val_loss: 0.9322 - val_accuracy: 0.5629
# Epoch 27/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.9079 - accuracy: 0.5709
# Epoch 27: val_loss did not improve from 0.91777
# 142/142 [==============================] - 1s 9ms/step - loss: 0.9079 - accuracy: 0.5707 - val_loss: 0.9288 - val_accuracy: 0.5691
# Epoch 28/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.9075 - accuracy: 0.5738
# Epoch 28: val_loss did not improve from 0.91777
# 142/142 [==============================] - 1s 9ms/step - loss: 0.9076 - accuracy: 0.5738 - val_loss: 0.9262 - val_accuracy: 0.5629
# Epoch 29/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.8986 - accuracy: 0.5788
# Epoch 29: val_loss improved from 0.91777 to 0.91544, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8977 - accuracy: 0.5808 - val_loss: 0.9154 - val_accuracy: 0.5825
# Epoch 30/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.8917 - accuracy: 0.5859
# Epoch 30: val_loss did not improve from 0.91544
# 142/142 [==============================] - 1s 9ms/step - loss: 0.8922 - accuracy: 0.5861 - val_loss: 0.9214 - val_accuracy: 0.5866
# Epoch 31/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.8972 - accuracy: 0.5822
# Epoch 31: val_loss improved from 0.91544 to 0.91482, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 1s 9ms/step - loss: 0.8970 - accuracy: 0.5822 - val_loss: 0.9148 - val_accuracy: 0.5907
# Epoch 32/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.8904 - accuracy: 0.5803
# Epoch 32: val_loss improved from 0.91482 to 0.90977, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 1s 9ms/step - loss: 0.8913 - accuracy: 0.5795 - val_loss: 0.9098 - val_accuracy: 0.5928
# Epoch 33/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.8931 - accuracy: 0.5797
# Epoch 33: val_loss did not improve from 0.90977
# 142/142 [==============================] - 1s 9ms/step - loss: 0.8926 - accuracy: 0.5808 - val_loss: 0.9108 - val_accuracy: 0.5784
# Epoch 34/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.8873 - accuracy: 0.5890
# Epoch 34: val_loss improved from 0.90977 to 0.90159, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 1s 9ms/step - loss: 0.8866 - accuracy: 0.5877 - val_loss: 0.9016 - val_accuracy: 0.5876
# Epoch 35/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.8894 - accuracy: 0.5816
# Epoch 35: val_loss did not improve from 0.90159
# 142/142 [==============================] - 1s 9ms/step - loss: 0.8891 - accuracy: 0.5819 - val_loss: 0.9056 - val_accuracy: 0.5938
# Epoch 36/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.8774 - accuracy: 0.5906
# Epoch 36: val_loss did not improve from 0.90159
# 142/142 [==============================] - 1s 9ms/step - loss: 0.8772 - accuracy: 0.5901 - val_loss: 0.9095 - val_accuracy: 0.5804
# Epoch 37/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.8857 - accuracy: 0.5929
# Epoch 37: val_loss did not improve from 0.90159
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8851 - accuracy: 0.5939 - val_loss: 0.9202 - val_accuracy: 0.5814
# Epoch 38/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.8768 - accuracy: 0.5951
# Epoch 38: val_loss did not improve from 0.90159
# 142/142 [==============================] - 1s 9ms/step - loss: 0.8777 - accuracy: 0.5952 - val_loss: 0.9149 - val_accuracy: 0.5701
# Epoch 39/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.8838 - accuracy: 0.5938
# Epoch 39: val_loss did not improve from 0.90159
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8837 - accuracy: 0.5941 - val_loss: 0.9019 - val_accuracy: 0.5876
# Epoch 40/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.8737 - accuracy: 0.5938
# Epoch 40: val_loss did not improve from 0.90159
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8729 - accuracy: 0.5943 - val_loss: 0.9093 - val_accuracy: 0.5866
# Epoch 41/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.8751 - accuracy: 0.5938
# Epoch 41: val_loss did not improve from 0.90159
# 142/142 [==============================] - 2s 11ms/step - loss: 0.8770 - accuracy: 0.5934 - val_loss: 0.9062 - val_accuracy: 0.5825
# Epoch 42/200
# 142/142 [==============================] - ETA: 0s - loss: 0.8624 - accuracy: 0.6056
# Epoch 42: val_loss did not improve from 0.90159
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8624 - accuracy: 0.6056 - val_loss: 0.9071 - val_accuracy: 0.5784
# Epoch 43/200
# 142/142 [==============================] - ETA: 0s - loss: 0.8636 - accuracy: 0.6016
# Epoch 43: val_loss did not improve from 0.90159
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8636 - accuracy: 0.6016 - val_loss: 0.9171 - val_accuracy: 0.5825
# Epoch 44/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.8715 - accuracy: 0.5994
# Epoch 44: val_loss did not improve from 0.90159
# 142/142 [==============================] - 2s 11ms/step - loss: 0.8715 - accuracy: 0.5998 - val_loss: 0.9080 - val_accuracy: 0.5918
# Epoch 45/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.8552 - accuracy: 0.6068
# Epoch 45: val_loss did not improve from 0.90159
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8550 - accuracy: 0.6067 - val_loss: 0.9080 - val_accuracy: 0.5897
# Epoch 46/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.8595 - accuracy: 0.6008
# Epoch 46: val_loss improved from 0.90159 to 0.90145, saving model to audio_classification_v1.0.hdf5
# 142/142 [==============================] - 2s 12ms/step - loss: 0.8585 - accuracy: 0.6016 - val_loss: 0.9014 - val_accuracy: 0.5918
# Epoch 47/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.8562 - accuracy: 0.6127
# Epoch 47: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8544 - accuracy: 0.6131 - val_loss: 0.9131 - val_accuracy: 0.5876
# Epoch 48/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.8494 - accuracy: 0.6119
# Epoch 48: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8487 - accuracy: 0.6120 - val_loss: 0.9091 - val_accuracy: 0.5907
# Epoch 49/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.8502 - accuracy: 0.6121
# Epoch 49: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8509 - accuracy: 0.6109 - val_loss: 0.9290 - val_accuracy: 0.5608
# Epoch 50/200
# 142/142 [==============================] - ETA: 0s - loss: 0.8511 - accuracy: 0.6120
# Epoch 50: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8511 - accuracy: 0.6120 - val_loss: 0.9101 - val_accuracy: 0.5948
# Epoch 51/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.8459 - accuracy: 0.6156
# Epoch 51: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8463 - accuracy: 0.6151 - val_loss: 0.9388 - val_accuracy: 0.5897
# Epoch 52/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.8381 - accuracy: 0.6164
# Epoch 52: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.8366 - accuracy: 0.6177 - val_loss: 0.9175 - val_accuracy: 0.5763
# Epoch 53/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.8345 - accuracy: 0.6159
# Epoch 53: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8354 - accuracy: 0.6159 - val_loss: 0.9103 - val_accuracy: 0.5938
# Epoch 54/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.8391 - accuracy: 0.6248
# Epoch 54: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8382 - accuracy: 0.6257 - val_loss: 0.9175 - val_accuracy: 0.5660
# Epoch 55/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.8413 - accuracy: 0.6216
# Epoch 55: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 11ms/step - loss: 0.8403 - accuracy: 0.6226 - val_loss: 0.9082 - val_accuracy: 0.5907
# Epoch 56/200
# 142/142 [==============================] - ETA: 0s - loss: 0.8185 - accuracy: 0.6330
# Epoch 56: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8185 - accuracy: 0.6330 - val_loss: 0.9319 - val_accuracy: 0.5722
# Epoch 57/200
# 142/142 [==============================] - ETA: 0s - loss: 0.8233 - accuracy: 0.6252
# Epoch 57: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 11ms/step - loss: 0.8233 - accuracy: 0.6252 - val_loss: 0.9160 - val_accuracy: 0.5918
# Epoch 58/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.8183 - accuracy: 0.6312
# Epoch 58: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.8193 - accuracy: 0.6303 - val_loss: 0.9189 - val_accuracy: 0.5876
# Epoch 59/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.8257 - accuracy: 0.6309
# Epoch 59: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8273 - accuracy: 0.6303 - val_loss: 0.9118 - val_accuracy: 0.5856
# Epoch 60/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.8127 - accuracy: 0.6315
# Epoch 60: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8133 - accuracy: 0.6316 - val_loss: 0.9330 - val_accuracy: 0.5845
# Epoch 61/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.8179 - accuracy: 0.6396
# Epoch 61: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8166 - accuracy: 0.6405 - val_loss: 0.9265 - val_accuracy: 0.5804
# Epoch 62/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.8177 - accuracy: 0.6299
# Epoch 62: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8179 - accuracy: 0.6301 - val_loss: 0.9198 - val_accuracy: 0.5825
# Epoch 63/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.8160 - accuracy: 0.6365
# Epoch 63: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8153 - accuracy: 0.6367 - val_loss: 0.9263 - val_accuracy: 0.5918
# Epoch 64/200
# 142/142 [==============================] - ETA: 0s - loss: 0.8151 - accuracy: 0.6283
# Epoch 64: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8151 - accuracy: 0.6283 - val_loss: 0.9119 - val_accuracy: 0.5897
# Epoch 65/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.8106 - accuracy: 0.6336
# Epoch 65: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.8116 - accuracy: 0.6341 - val_loss: 0.9335 - val_accuracy: 0.5773
# Epoch 66/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.8042 - accuracy: 0.6428
# Epoch 66: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.8053 - accuracy: 0.6424 - val_loss: 0.9337 - val_accuracy: 0.5680
# Epoch 67/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.7926 - accuracy: 0.6515
# Epoch 67: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.7933 - accuracy: 0.6504 - val_loss: 0.9221 - val_accuracy: 0.5773
# Epoch 68/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.7869 - accuracy: 0.6574
# Epoch 68: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7879 - accuracy: 0.6561 - val_loss: 0.9173 - val_accuracy: 0.5876
# Epoch 69/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.7779 - accuracy: 0.6529
# Epoch 69: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7786 - accuracy: 0.6530 - val_loss: 0.9282 - val_accuracy: 0.5753
# Epoch 70/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.7935 - accuracy: 0.6538
# Epoch 70: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7944 - accuracy: 0.6524 - val_loss: 0.9257 - val_accuracy: 0.5794
# Epoch 71/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.7925 - accuracy: 0.6405
# Epoch 71: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7919 - accuracy: 0.6409 - val_loss: 0.9438 - val_accuracy: 0.5835
# Epoch 72/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.7869 - accuracy: 0.6540
# Epoch 72: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.7870 - accuracy: 0.6539 - val_loss: 0.9378 - val_accuracy: 0.5825
# Epoch 73/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.7757 - accuracy: 0.6596
# Epoch 73: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7759 - accuracy: 0.6601 - val_loss: 0.9572 - val_accuracy: 0.5814
# Epoch 74/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.7714 - accuracy: 0.6605
# Epoch 74: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7732 - accuracy: 0.6612 - val_loss: 0.9475 - val_accuracy: 0.5732
# Epoch 75/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.7833 - accuracy: 0.6505
# Epoch 75: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7842 - accuracy: 0.6497 - val_loss: 0.9128 - val_accuracy: 0.5856
# Epoch 76/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.7712 - accuracy: 0.6675
# Epoch 76: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7711 - accuracy: 0.6685 - val_loss: 0.9355 - val_accuracy: 0.5835
# Epoch 77/200
# 142/142 [==============================] - ETA: 0s - loss: 0.7683 - accuracy: 0.6572
# Epoch 77: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.7683 - accuracy: 0.6572 - val_loss: 0.9477 - val_accuracy: 0.5784
# Epoch 78/200
# 142/142 [==============================] - ETA: 0s - loss: 0.7641 - accuracy: 0.6599
# Epoch 78: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7641 - accuracy: 0.6599 - val_loss: 0.9282 - val_accuracy: 0.5691
# Epoch 79/200
# 142/142 [==============================] - ETA: 0s - loss: 0.7585 - accuracy: 0.6577
# Epoch 79: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7585 - accuracy: 0.6577 - val_loss: 0.9522 - val_accuracy: 0.5680
# Epoch 80/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.7498 - accuracy: 0.6680
# Epoch 80: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7489 - accuracy: 0.6692 - val_loss: 0.9516 - val_accuracy: 0.5784
# Epoch 81/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.7535 - accuracy: 0.6782
# Epoch 81: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7538 - accuracy: 0.6773 - val_loss: 0.9453 - val_accuracy: 0.5753
# Epoch 82/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.7565 - accuracy: 0.6738
# Epoch 82: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7556 - accuracy: 0.6747 - val_loss: 0.9454 - val_accuracy: 0.5804
# Epoch 83/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.7315 - accuracy: 0.6797
# Epoch 83: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7328 - accuracy: 0.6798 - val_loss: 0.9718 - val_accuracy: 0.5804
# Epoch 84/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.7440 - accuracy: 0.6772
# Epoch 84: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7442 - accuracy: 0.6769 - val_loss: 0.9546 - val_accuracy: 0.5670
# Epoch 85/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.7362 - accuracy: 0.6753
# Epoch 85: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7364 - accuracy: 0.6754 - val_loss: 0.9442 - val_accuracy: 0.5763
# Epoch 86/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.7347 - accuracy: 0.6802
# Epoch 86: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7351 - accuracy: 0.6795 - val_loss: 0.9475 - val_accuracy: 0.5866
# Epoch 87/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.7222 - accuracy: 0.6850
# Epoch 87: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7236 - accuracy: 0.6840 - val_loss: 1.0018 - val_accuracy: 0.5814
# Epoch 88/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.7314 - accuracy: 0.6772
# Epoch 88: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7318 - accuracy: 0.6773 - val_loss: 0.9738 - val_accuracy: 0.5794
# Epoch 89/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.7247 - accuracy: 0.6904
# Epoch 89: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7271 - accuracy: 0.6893 - val_loss: 1.0129 - val_accuracy: 0.5670
# Epoch 90/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.7780 - accuracy: 0.6801
# Epoch 90: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7782 - accuracy: 0.6789 - val_loss: 1.0147 - val_accuracy: 0.5557
# Epoch 91/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.7246 - accuracy: 0.6877
# Epoch 91: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7239 - accuracy: 0.6879 - val_loss: 0.9439 - val_accuracy: 0.5680
# Epoch 92/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.7248 - accuracy: 0.6848
# Epoch 92: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7231 - accuracy: 0.6864 - val_loss: 0.9646 - val_accuracy: 0.5825
# Epoch 93/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.7089 - accuracy: 0.6882
# Epoch 93: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7101 - accuracy: 0.6879 - val_loss: 0.9797 - val_accuracy: 0.5412
# Epoch 94/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.7187 - accuracy: 0.6875
# Epoch 94: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7204 - accuracy: 0.6871 - val_loss: 0.9918 - val_accuracy: 0.5722
# Epoch 95/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.7171 - accuracy: 0.6862
# Epoch 95: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7162 - accuracy: 0.6864 - val_loss: 0.9876 - val_accuracy: 0.5732
# Epoch 96/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.7155 - accuracy: 0.6846
# Epoch 96: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7175 - accuracy: 0.6829 - val_loss: 0.9517 - val_accuracy: 0.5845
# Epoch 97/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.7049 - accuracy: 0.6955
# Epoch 97: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7071 - accuracy: 0.6935 - val_loss: 0.9619 - val_accuracy: 0.5856
# Epoch 98/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.7050 - accuracy: 0.7005
# Epoch 98: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7042 - accuracy: 0.7008 - val_loss: 0.9587 - val_accuracy: 0.5825
# Epoch 99/200
# 142/142 [==============================] - ETA: 0s - loss: 0.7024 - accuracy: 0.6915
# Epoch 99: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7024 - accuracy: 0.6915 - val_loss: 0.9826 - val_accuracy: 0.5784
# Epoch 100/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.7035 - accuracy: 0.6989
# Epoch 100: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7053 - accuracy: 0.6974 - val_loss: 0.9926 - val_accuracy: 0.5577
# Epoch 101/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.7183 - accuracy: 0.7003
# Epoch 101: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.7204 - accuracy: 0.6985 - val_loss: 0.9562 - val_accuracy: 0.5722
# Epoch 102/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.6965 - accuracy: 0.6978
# Epoch 102: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.6963 - accuracy: 0.6977 - val_loss: 0.9880 - val_accuracy: 0.5773
# Epoch 103/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.6953 - accuracy: 0.7077
# Epoch 103: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.6950 - accuracy: 0.7083 - val_loss: 0.9786 - val_accuracy: 0.5773
# Epoch 104/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.6935 - accuracy: 0.7113
# Epoch 104: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.6941 - accuracy: 0.7114 - val_loss: 0.9557 - val_accuracy: 0.5742
# Epoch 105/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.6726 - accuracy: 0.7168
# Epoch 105: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.6722 - accuracy: 0.7173 - val_loss: 1.0296 - val_accuracy: 0.5567
# Epoch 106/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.6736 - accuracy: 0.7080
# Epoch 106: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.6768 - accuracy: 0.7069 - val_loss: 1.0058 - val_accuracy: 0.5784
# Epoch 107/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.6814 - accuracy: 0.7102
# Epoch 107: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.6831 - accuracy: 0.7078 - val_loss: 0.9812 - val_accuracy: 0.5691
# Epoch 108/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.6726 - accuracy: 0.7165
# Epoch 108: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.6721 - accuracy: 0.7162 - val_loss: 1.0083 - val_accuracy: 0.5691
# Epoch 109/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.6678 - accuracy: 0.7135
# Epoch 109: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.6694 - accuracy: 0.7144 - val_loss: 0.9817 - val_accuracy: 0.5680
# Epoch 110/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.6522 - accuracy: 0.7208
# Epoch 110: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.6531 - accuracy: 0.7211 - val_loss: 1.0470 - val_accuracy: 0.5670
# Epoch 111/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.6542 - accuracy: 0.7196
# Epoch 111: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.6562 - accuracy: 0.7191 - val_loss: 1.0189 - val_accuracy: 0.5629
# Epoch 112/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.6523 - accuracy: 0.7246
# Epoch 112: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.6555 - accuracy: 0.7235 - val_loss: 1.0164 - val_accuracy: 0.5680
# Epoch 113/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.6687 - accuracy: 0.7138
# Epoch 113: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 9ms/step - loss: 0.6669 - accuracy: 0.7153 - val_loss: 1.0477 - val_accuracy: 0.5784
# Epoch 114/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.6662 - accuracy: 0.7201
# Epoch 114: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.6669 - accuracy: 0.7208 - val_loss: 1.0201 - val_accuracy: 0.5794
# Epoch 115/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.6587 - accuracy: 0.7242
# Epoch 115: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 9ms/step - loss: 0.6574 - accuracy: 0.7246 - val_loss: 1.0124 - val_accuracy: 0.5784
# Epoch 116/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.6504 - accuracy: 0.7276
# Epoch 116: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 9ms/step - loss: 0.6491 - accuracy: 0.7275 - val_loss: 1.1109 - val_accuracy: 0.5866
# Epoch 117/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.6524 - accuracy: 0.7258
# Epoch 117: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 9ms/step - loss: 0.6538 - accuracy: 0.7244 - val_loss: 1.0582 - val_accuracy: 0.5598
# Epoch 118/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.6560 - accuracy: 0.7259
# Epoch 118: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.6541 - accuracy: 0.7270 - val_loss: 1.0019 - val_accuracy: 0.5794
# Epoch 119/200
# 136/142 [===========================>..] - ETA: 0s - loss: 0.6546 - accuracy: 0.7277
# Epoch 119: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 9ms/step - loss: 0.6587 - accuracy: 0.7259 - val_loss: 1.0184 - val_accuracy: 0.5670
# Epoch 120/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.6518 - accuracy: 0.7185
# Epoch 120: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 9ms/step - loss: 0.6510 - accuracy: 0.7189 - val_loss: 1.0510 - val_accuracy: 0.5732
# Epoch 121/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.6403 - accuracy: 0.7329
# Epoch 121: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.6407 - accuracy: 0.7326 - val_loss: 1.1142 - val_accuracy: 0.5845
# Epoch 122/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.6516 - accuracy: 0.7217
# Epoch 122: val_loss did not improve from 0.90145
# 142/142 [==============================] - 1s 10ms/step - loss: 0.6511 - accuracy: 0.7224 - val_loss: 1.0144 - val_accuracy: 0.5897
# Epoch 123/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.6367 - accuracy: 0.7275
# Epoch 123: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 14ms/step - loss: 0.6369 - accuracy: 0.7275 - val_loss: 1.0970 - val_accuracy: 0.5701
# Epoch 124/200
# 142/142 [==============================] - ETA: 0s - loss: 0.6354 - accuracy: 0.7359
# Epoch 124: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.6354 - accuracy: 0.7359 - val_loss: 1.0466 - val_accuracy: 0.5845
# Epoch 125/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.6241 - accuracy: 0.7334
# Epoch 125: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 13ms/step - loss: 0.6241 - accuracy: 0.7334 - val_loss: 1.0379 - val_accuracy: 0.5753
# Epoch 126/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.6101 - accuracy: 0.7446
# Epoch 126: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.6123 - accuracy: 0.7438 - val_loss: 1.0683 - val_accuracy: 0.5711
# Epoch 127/200
# 142/142 [==============================] - ETA: 0s - loss: 0.6242 - accuracy: 0.7370
# Epoch 127: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.6242 - accuracy: 0.7370 - val_loss: 1.0451 - val_accuracy: 0.5763
# Epoch 128/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.6156 - accuracy: 0.7417
# Epoch 128: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 13ms/step - loss: 0.6142 - accuracy: 0.7425 - val_loss: 1.1099 - val_accuracy: 0.5660
# Epoch 129/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.6243 - accuracy: 0.7440
# Epoch 129: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 13ms/step - loss: 0.6240 - accuracy: 0.7438 - val_loss: 1.0982 - val_accuracy: 0.5639
# Epoch 130/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.6174 - accuracy: 0.7441
# Epoch 130: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 14ms/step - loss: 0.6181 - accuracy: 0.7429 - val_loss: 1.0430 - val_accuracy: 0.5701
# Epoch 131/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.6341 - accuracy: 0.7449
# Epoch 131: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 17ms/step - loss: 0.6336 - accuracy: 0.7449 - val_loss: 1.0531 - val_accuracy: 0.5732
# Epoch 132/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.6195 - accuracy: 0.7422
# Epoch 132: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 13ms/step - loss: 0.6199 - accuracy: 0.7423 - val_loss: 1.0403 - val_accuracy: 0.5773
# Epoch 133/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.6217 - accuracy: 0.7434
# Epoch 133: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 13ms/step - loss: 0.6221 - accuracy: 0.7429 - val_loss: 1.0433 - val_accuracy: 0.5784
# Epoch 134/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.6066 - accuracy: 0.7415
# Epoch 134: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.6048 - accuracy: 0.7423 - val_loss: 1.0613 - val_accuracy: 0.5784
# Epoch 135/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.6110 - accuracy: 0.7476
# Epoch 135: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.6111 - accuracy: 0.7478 - val_loss: 1.0411 - val_accuracy: 0.5845
# Epoch 136/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.5908 - accuracy: 0.7527
# Epoch 136: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5903 - accuracy: 0.7533 - val_loss: 1.2003 - val_accuracy: 0.5629
# Epoch 137/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.6219 - accuracy: 0.7489
# Epoch 137: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.6259 - accuracy: 0.7471 - val_loss: 1.0159 - val_accuracy: 0.5814
# Epoch 138/200
# 142/142 [==============================] - ETA: 0s - loss: 0.6037 - accuracy: 0.7449
# Epoch 138: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.6037 - accuracy: 0.7449 - val_loss: 1.1237 - val_accuracy: 0.5753
# Epoch 139/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.6026 - accuracy: 0.7507
# Epoch 139: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.6008 - accuracy: 0.7518 - val_loss: 1.1335 - val_accuracy: 0.5753
# Epoch 140/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.6043 - accuracy: 0.7473
# Epoch 140: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.6057 - accuracy: 0.7469 - val_loss: 1.0911 - val_accuracy: 0.5639
# Epoch 141/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.5839 - accuracy: 0.7547
# Epoch 141: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5845 - accuracy: 0.7553 - val_loss: 1.0669 - val_accuracy: 0.5742
# Epoch 142/200
# 142/142 [==============================] - ETA: 0s - loss: 0.6031 - accuracy: 0.7557
# Epoch 142: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.6031 - accuracy: 0.7557 - val_loss: 1.0274 - val_accuracy: 0.5701
# Epoch 143/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.5892 - accuracy: 0.7551
# Epoch 143: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5908 - accuracy: 0.7546 - val_loss: 1.0726 - val_accuracy: 0.5773
# Epoch 144/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.6029 - accuracy: 0.7504
# Epoch 144: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.6021 - accuracy: 0.7507 - val_loss: 1.0708 - val_accuracy: 0.5918
# Epoch 145/200
# 142/142 [==============================] - ETA: 0s - loss: 0.5936 - accuracy: 0.7535
# Epoch 145: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5936 - accuracy: 0.7535 - val_loss: 1.0895 - val_accuracy: 0.5660
# Epoch 146/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.6143 - accuracy: 0.7430
# Epoch 146: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.6127 - accuracy: 0.7432 - val_loss: 1.0759 - val_accuracy: 0.5845
# Epoch 147/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.6004 - accuracy: 0.7498
# Epoch 147: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.5998 - accuracy: 0.7500 - val_loss: 1.0788 - val_accuracy: 0.5763
# Epoch 148/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.5796 - accuracy: 0.7640
# Epoch 148: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5800 - accuracy: 0.7635 - val_loss: 1.0673 - val_accuracy: 0.5876
# Epoch 149/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.5987 - accuracy: 0.7563
# Epoch 149: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.5998 - accuracy: 0.7553 - val_loss: 1.0932 - val_accuracy: 0.5814
# Epoch 150/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.5953 - accuracy: 0.7594
# Epoch 150: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.5971 - accuracy: 0.7586 - val_loss: 1.0621 - val_accuracy: 0.5753
# Epoch 151/200
# 142/142 [==============================] - ETA: 0s - loss: 0.5895 - accuracy: 0.7597
# Epoch 151: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5895 - accuracy: 0.7597 - val_loss: 1.0728 - val_accuracy: 0.5639
# Epoch 152/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.5861 - accuracy: 0.7600
# Epoch 152: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5854 - accuracy: 0.7606 - val_loss: 1.1848 - val_accuracy: 0.5629
# Epoch 153/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.5757 - accuracy: 0.7637
# Epoch 153: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5789 - accuracy: 0.7619 - val_loss: 1.1849 - val_accuracy: 0.5711
# Epoch 154/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.5671 - accuracy: 0.7676
# Epoch 154: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.5665 - accuracy: 0.7681 - val_loss: 1.1810 - val_accuracy: 0.5835
# Epoch 155/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.5699 - accuracy: 0.7643
# Epoch 155: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 13ms/step - loss: 0.5689 - accuracy: 0.7648 - val_loss: 1.2012 - val_accuracy: 0.5804
# Epoch 156/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.5796 - accuracy: 0.7680
# Epoch 156: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5797 - accuracy: 0.7681 - val_loss: 1.0676 - val_accuracy: 0.5856
# Epoch 157/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.5517 - accuracy: 0.7678
# Epoch 157: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5516 - accuracy: 0.7686 - val_loss: 1.2220 - val_accuracy: 0.5732
# Epoch 158/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.5596 - accuracy: 0.7721
# Epoch 158: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.5596 - accuracy: 0.7725 - val_loss: 1.2145 - val_accuracy: 0.5680
# Epoch 159/200
# 137/142 [===========================>..] - ETA: 0s - loss: 0.5611 - accuracy: 0.7760
# Epoch 159: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.5640 - accuracy: 0.7736 - val_loss: 1.1983 - val_accuracy: 0.5680
# Epoch 160/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.5739 - accuracy: 0.7697
# Epoch 160: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5743 - accuracy: 0.7692 - val_loss: 1.1321 - val_accuracy: 0.5825
# Epoch 161/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.5618 - accuracy: 0.7725
# Epoch 161: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5598 - accuracy: 0.7741 - val_loss: 1.1646 - val_accuracy: 0.5649
# Epoch 162/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.5655 - accuracy: 0.7663
# Epoch 162: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.5655 - accuracy: 0.7657 - val_loss: 1.2247 - val_accuracy: 0.5722
# Epoch 163/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.5537 - accuracy: 0.7663
# Epoch 163: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5546 - accuracy: 0.7661 - val_loss: 1.1804 - val_accuracy: 0.5691
# Epoch 164/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.5652 - accuracy: 0.7754
# Epoch 164: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5657 - accuracy: 0.7745 - val_loss: 1.1848 - val_accuracy: 0.5711
# Epoch 165/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.5688 - accuracy: 0.7685
# Epoch 165: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 13ms/step - loss: 0.5677 - accuracy: 0.7686 - val_loss: 1.1324 - val_accuracy: 0.5660
# Epoch 166/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.5486 - accuracy: 0.7808
# Epoch 166: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5480 - accuracy: 0.7814 - val_loss: 1.1597 - val_accuracy: 0.5711
# Epoch 167/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.5521 - accuracy: 0.7768
# Epoch 167: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5537 - accuracy: 0.7761 - val_loss: 1.1714 - val_accuracy: 0.5804
# Epoch 168/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.5547 - accuracy: 0.7698
# Epoch 168: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5525 - accuracy: 0.7705 - val_loss: 1.2466 - val_accuracy: 0.5856
# Epoch 169/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.5557 - accuracy: 0.7842
# Epoch 169: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5566 - accuracy: 0.7833 - val_loss: 1.1944 - val_accuracy: 0.5784
# Epoch 170/200
# 142/142 [==============================] - ETA: 0s - loss: 0.5478 - accuracy: 0.7752
# Epoch 170: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.5478 - accuracy: 0.7752 - val_loss: 1.1433 - val_accuracy: 0.5629
# Epoch 171/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.5496 - accuracy: 0.7781
# Epoch 171: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5489 - accuracy: 0.7785 - val_loss: 1.2167 - val_accuracy: 0.5773
# Epoch 172/200
# 142/142 [==============================] - ETA: 0s - loss: 0.5587 - accuracy: 0.7708
# Epoch 172: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5587 - accuracy: 0.7708 - val_loss: 1.2737 - val_accuracy: 0.5639
# Epoch 173/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.5438 - accuracy: 0.7826
# Epoch 173: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 13ms/step - loss: 0.5445 - accuracy: 0.7829 - val_loss: 1.2219 - val_accuracy: 0.5753
# Epoch 174/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.5420 - accuracy: 0.7783
# Epoch 174: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 13ms/step - loss: 0.5418 - accuracy: 0.7787 - val_loss: 1.1761 - val_accuracy: 0.5629
# Epoch 175/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.5474 - accuracy: 0.7730
# Epoch 175: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.5458 - accuracy: 0.7741 - val_loss: 1.2283 - val_accuracy: 0.5753
# Epoch 176/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.5371 - accuracy: 0.7797
# Epoch 176: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 13ms/step - loss: 0.5382 - accuracy: 0.7798 - val_loss: 1.1662 - val_accuracy: 0.5856
# Epoch 177/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.5574 - accuracy: 0.7790
# Epoch 177: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5570 - accuracy: 0.7794 - val_loss: 1.1597 - val_accuracy: 0.5887
# Epoch 178/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.5531 - accuracy: 0.7775
# Epoch 178: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5531 - accuracy: 0.7776 - val_loss: 1.1438 - val_accuracy: 0.5784
# Epoch 179/200
# 142/142 [==============================] - ETA: 0s - loss: 0.5275 - accuracy: 0.7829
# Epoch 179: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5275 - accuracy: 0.7829 - val_loss: 1.2638 - val_accuracy: 0.5784
# Epoch 180/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.5444 - accuracy: 0.7833
# Epoch 180: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.5452 - accuracy: 0.7820 - val_loss: 1.1574 - val_accuracy: 0.5794
# Epoch 181/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.5503 - accuracy: 0.7726
# Epoch 181: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 13ms/step - loss: 0.5491 - accuracy: 0.7723 - val_loss: 1.1528 - val_accuracy: 0.5722
# Epoch 182/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.5297 - accuracy: 0.7837
# Epoch 182: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5293 - accuracy: 0.7836 - val_loss: 1.2311 - val_accuracy: 0.5773
# Epoch 183/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.5470 - accuracy: 0.7819
# Epoch 183: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5471 - accuracy: 0.7818 - val_loss: 1.1671 - val_accuracy: 0.5856
# Epoch 184/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.5370 - accuracy: 0.7857
# Epoch 184: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5380 - accuracy: 0.7856 - val_loss: 1.2052 - val_accuracy: 0.5660
# Epoch 185/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.5522 - accuracy: 0.7723
# Epoch 185: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.5509 - accuracy: 0.7730 - val_loss: 1.1258 - val_accuracy: 0.5835
# Epoch 186/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.5325 - accuracy: 0.7841
# Epoch 186: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5322 - accuracy: 0.7845 - val_loss: 1.1743 - val_accuracy: 0.5763
# Epoch 187/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.5239 - accuracy: 0.7831
# Epoch 187: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5206 - accuracy: 0.7853 - val_loss: 1.2722 - val_accuracy: 0.5608
# Epoch 188/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.5339 - accuracy: 0.7835
# Epoch 188: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5341 - accuracy: 0.7838 - val_loss: 1.1618 - val_accuracy: 0.5897
# Epoch 189/200
# 142/142 [==============================] - ETA: 0s - loss: 0.4991 - accuracy: 0.7995
# Epoch 189: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.4991 - accuracy: 0.7995 - val_loss: 1.2251 - val_accuracy: 0.5845
# Epoch 190/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.5242 - accuracy: 0.7875
# Epoch 190: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.5239 - accuracy: 0.7875 - val_loss: 1.1975 - val_accuracy: 0.5784
# Epoch 191/200
# 140/142 [============================>.] - ETA: 0s - loss: 0.5398 - accuracy: 0.7826
# Epoch 191: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5402 - accuracy: 0.7827 - val_loss: 1.3272 - val_accuracy: 0.5814
# Epoch 192/200
# 142/142 [==============================] - ETA: 0s - loss: 0.5221 - accuracy: 0.7946
# Epoch 192: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5221 - accuracy: 0.7946 - val_loss: 1.1538 - val_accuracy: 0.5670
# Epoch 193/200
# 138/142 [============================>.] - ETA: 0s - loss: 0.5206 - accuracy: 0.7928
# Epoch 193: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.5184 - accuracy: 0.7939 - val_loss: 1.2428 - val_accuracy: 0.5866
# Epoch 194/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.5312 - accuracy: 0.7895
# Epoch 194: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5316 - accuracy: 0.7891 - val_loss: 1.3013 - val_accuracy: 0.5660
# Epoch 195/200
# 142/142 [==============================] - ETA: 0s - loss: 0.5273 - accuracy: 0.7860
# Epoch 195: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5273 - accuracy: 0.7860 - val_loss: 1.2957 - val_accuracy: 0.5711
# Epoch 196/200
# 142/142 [==============================] - ETA: 0s - loss: 0.5338 - accuracy: 0.7849
# Epoch 196: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.5338 - accuracy: 0.7849 - val_loss: 1.2176 - val_accuracy: 0.5773
# Epoch 197/200
# 139/142 [============================>.] - ETA: 0s - loss: 0.5267 - accuracy: 0.7950
# Epoch 197: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 13ms/step - loss: 0.5252 - accuracy: 0.7953 - val_loss: 1.2109 - val_accuracy: 0.5856
# Epoch 198/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.5212 - accuracy: 0.7926
# Epoch 198: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5212 - accuracy: 0.7926 - val_loss: 1.2059 - val_accuracy: 0.5753
# Epoch 199/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.5132 - accuracy: 0.7932
# Epoch 199: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 12ms/step - loss: 0.5143 - accuracy: 0.7924 - val_loss: 1.2189 - val_accuracy: 0.5928
# Epoch 200/200
# 141/142 [============================>.] - ETA: 0s - loss: 0.5142 - accuracy: 0.7928
# Epoch 200: val_loss did not improve from 0.90145
# 142/142 [==============================] - 2s 11ms/step - loss: 0.5142 - accuracy: 0.7926 - val_loss: 1.2744 - val_accuracy: 0.5887
# Training completed in time:  0:05:11.560161

# %%
# Check accuracy
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.5705458521842957

# %%
X_test[1]
# Out:
# array([-4.63172760e+02,  4.47161484e+01, -1.40991993e+01,  1.42216361e+00,
#        -2.24697437e+01, -4.97956753e+00, -1.35839357e+01,  1.79930508e+00,
#        -1.47846127e+01, -7.46276522e+00,  4.28938180e-01, -2.80062103e+00,
#        -5.37157774e-01, -5.47485542e+00,  5.18402147e+00, -4.19928789e+00,
#        -1.52063429e+00, -2.82611704e+00, -3.32008028e+00, -1.51369846e+00,
#        -2.39291596e+00,  2.22613797e-01, -2.47722673e+00,  9.85216379e-01,
#         1.37508857e+00,  4.33293045e-01, -5.10542512e-01, -1.18397012e-01,
#         2.54271150e-01,  5.81427574e-01,  1.18769622e+00,  2.48495603e+00,
#         2.92968780e-01, -1.69974875e+00,  8.46230865e-01,  7.19334483e-01,
#         2.35539958e-01,  7.07976758e-01,  2.26236835e-01, -1.10791993e+00,
#         1.10408652e+00,  9.15231109e-01, -6.65493846e-01,  8.51423740e-01,
#         5.87742984e-01,  4.53982472e-01,  1.25110376e+00,  5.06664574e-01,
#         1.59177348e-01, -5.27964719e-02, -1.72388524e-01, -2.83571221e-02,
#        -7.60042667e-01,  9.71054211e-02, -1.24804415e-01, -5.61520517e-01,
#        -4.36663449e-01, -3.08437556e-01, -9.71963108e-02, -5.82434535e-01,
#        -3.33933830e-01, -1.86881796e-01, -4.99471933e-01, -4.18240130e-01,
#         3.10254276e-01,  2.52652705e-01, -1.91660404e-01, -4.38350998e-02,
#         4.35937405e-01, -3.75832729e-02,  2.86630124e-01,  6.34634018e-01,
#        -2.05009326e-01, -3.15945923e-01,  8.72273594e-02,  4.45660859e-01,
#        -2.80779362e-01, -1.09060585e-01,  2.63923496e-01, -8.65933299e-02,
#         2.23123327e-01,  2.99602091e-01, -4.09217924e-01, -2.20824480e-01,
#         3.61477792e-01, -1.23001397e-01, -2.18671560e-01,  7.87723586e-02,
#        -1.92151651e-01, -6.79389983e-02,  2.91384429e-01, -4.09213036e-01,
#        -1.83213085e-01,  1.41407568e-02, -2.72764117e-01, -1.51937649e-01,
#        -1.54168665e-01, -1.60048291e-01, -2.36195117e-01, -1.87522262e-01,
#        -2.08016798e-01,  2.33038172e-01,  2.80685455e-01,  1.05733745e-01,
#         3.06858271e-02,  1.25632450e-01, -8.71214718e-02,  2.04227977e-02,
#         2.71555662e-01, -9.74809825e-02,  3.27302516e-01,  1.70724452e-01,
#        -2.46437509e-02,  2.32011676e-01, -3.09347315e-03, -5.67459874e-02,
#         1.08574562e-01, -6.72105625e-02,  1.91456079e-01,  3.19932997e-02,
#         2.44099903e-03,  4.04131366e-03,  4.77478374e-03,  9.33673419e-03,
#         5.18069416e-02,  4.53660488e-01,  2.58948135e+00,  5.99003601e+00,
#         5.53039980e+00,  6.47111511e+00,  4.31813669e+00,  1.42554665e+00,
#         1.31867588e+00,  1.86827826e+00,  2.77886367e+00,  3.33055377e+00,
#         7.40049505e+00,  6.05238724e+00,  6.77469110e+00,  5.94972134e+00,
#         4.67091370e+00,  3.13546848e+00,  1.56068563e+00,  1.29388869e+00,
#         1.74724519e+00,  2.09211659e+00,  8.01233888e-01,  5.01845777e-01,
#         4.28745657e-01,  4.34933603e-01,  7.97265589e-01,  6.71899617e-01,
#         5.63543916e-01,  4.50956285e-01,  4.88443673e-01,  2.62791008e-01,
#         2.90419161e-01,  3.54344517e-01,  3.93095732e-01,  4.92544264e-01,
#         6.42683029e-01,  5.09009540e-01,  2.68847942e-01,  1.15611762e-01,
#         9.96467844e-02,  1.20321296e-01,  1.26151785e-01,  2.09818274e-01,
#         2.78858542e-01,  8.63173082e-02,  5.13636321e-02,  4.07070518e-02,
#         4.34175171e-02,  3.74509692e-02,  3.78899612e-02,  2.28863694e-02,
#         1.30406031e-02,  1.68440621e-02,  2.76023280e-02,  7.37888590e-02,
#         6.97320476e-02,  9.34706703e-02,  8.34836289e-02,  8.31891298e-02,
#         4.41436954e-02,  3.65494639e-02,  8.03006291e-02,  2.89229155e-01,
#         3.68747562e-01,  1.79417223e-01,  2.38081947e-01,  3.00810993e-01,
#         6.92447126e-02,  4.46471237e-02,  5.31205684e-02,  5.40900528e-02,
#         4.98229638e-02,  8.52327347e-02,  2.94208936e-02,  6.63120858e-03,
#         1.68705937e-02,  8.82628374e-03,  3.35480757e-02,  5.57016395e-02,
#         3.86893861e-02,  3.60886045e-02,  1.33914798e-02,  1.12267528e-02,
#         9.48015973e-03,  1.70449018e-02,  8.38791672e-03,  7.50976847e-03,
#         5.50454855e-03,  1.39252860e-02,  9.15344059e-03,  2.06231829e-02,
#         1.63382404e-02,  3.21773365e-02,  3.00251041e-02,  3.52754742e-02,
#         3.86153087e-02,  2.42875293e-02,  2.18057614e-02,  1.20109487e-02,
#         8.19359627e-03,  3.89405899e-03,  1.70940219e-03,  3.47898400e-04,
#         8.95318444e-05,  2.08981892e-05,  5.35068693e-07,  3.47361038e-08,
#         4.88106044e-09,  3.42002493e-09,  3.49650020e-09,  3.21949645e-09,
#         3.98540001e-09,  2.03399808e-09,  1.13355036e-09,  1.33772313e-10],
#       dtype=float32)

# %%
model.predict(X_test)
# Out:
# 31/31 [==============================] - 0s 5ms/step
# array([[4.8885725e-02, 7.7785784e-01, 1.7325643e-01],
#        [1.3986437e-01, 2.4706696e-01, 6.1306864e-01],
#        [2.4988931e-02, 8.4241045e-01, 1.3260062e-01],
#        ...,
#        [2.0002069e-01, 3.1208640e-01, 4.8789296e-01],
#        [6.8570545e-05, 8.7789203e-06, 9.9992263e-01],
#        [5.8179583e-02, 7.4443221e-01, 1.9738819e-01]], dtype=float32)

# %%
# BUILD A CNN MODEL

# %%
# Preprocess the data to match proper input shape for CNN

# %%
# Define the Model

# %%
# Compile the model with loss and optimizer

# %%
# Train the model

# %%
# Check the accuracy score

# %%
# BUILD A LSTM MODEL

# %%
# Preprocess the data to match proper input shape for LSTM

# %%
# Define the Model

# %%
# Compile the model with loss and optimizer

# %%
# Train the model

# %%
# Check the accuracy score
